# %% [markdown]
# # PLA Degradation Predictor Exploration
#
# This notebook provides a playground to explore the UMA model and test the structure generation pipeline.

# %%
import sys
import os
sys.path.append(os.path.abspath('../src'))

import numpy as np
import matplotlib.pyplot as plt

# Import custom modules
# from structure_generator import build_pla_oligomer
# from uma_calculator import setup_calculator, calculate_hydrolysis_reaction_energy
# from bep_calibrator import fit_bep_line
# from half_life_predictor import predict_half_life

print("Environment ready.")
